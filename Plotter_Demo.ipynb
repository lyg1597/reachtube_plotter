# %%
from plotter.plotter2D import plot 
from plotter.parser import Parser
# %matplotlib inline
# %matplotlib qt

# %%
f = open('./reachtube_billiard.txt','r')
parser1 = Parser(f)
data = parser1.get_all_data()
fig = plot(data, 1, [2])
# fig.show()

# %%
f = open('./reachtube_vanderpol.txt','r')
parser1 = Parser(f)
data = parser1.get_all_data()
fig = plot(data, 0, [1,2])
# fig.show()
